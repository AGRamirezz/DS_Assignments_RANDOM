# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/Users/adolf/Documents/DS_Portfolio/Data_Sets/pro-evolution-soccer-pes-2019-players-dataset/PES2019.csv')
df1
# Out:
#       Position   Player Name          Team Name Nationality  Height  Weight  \
# 0           CF    C. RONALDO     PM BLACK WHITE    PORTUGAL     185      80
# 1           SS      L. MESSI          BARCELONA   ARGENTINA     170      72
# 2          LWF        NEYMAR                PSG      BRAZIL     175      68
# 3           GK  DAVID DE GEA            MAN RED       SPAIN     192      76
# 4           GK      M. NEUER        Free Agents     GERMANY     193      92
# ...        ...           ...                ...         ...     ...     ...
# 11143       GK       R. FROM       NORDSJÆLLAND     DENMARK     180      78
# 11144       CB      G. MUTLU        AKHİSARSPOR      TURKEY     170      68
# 11145      CMF   ZHU ZHENGYU      SHANGHAI SIPG       CHINA     178      71
# 11146       GK    A. CÁCERES    UNIÓN LA CALERA       CHILE     175      72
# 11147      AMF     B. KIRDAR  MELBOURNE VICTORY   AUSTRALIA     178      75
#
#        Age Condition  Overall Rating
# ...

# %%
## DATA SUMMARY
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11148 entries, 0 to 11147
# Data columns (total 9 columns):
# Position          11148 non-null object
# Player Name       11148 non-null object
# Team Name         11148 non-null object
# Nationality       11148 non-null object
# Height            11148 non-null int64
# Weight            11148 non-null int64
# Age               11148 non-null int64
# Condition         11148 non-null object
# Overall Rating    11148 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 566.2+ KB

# %%
df1.nunique()
# Out:
# Position             13
# Player Name       10593
# Team Name           372
# Nationality         147
# Height               48
# Weight               51
# Age                  28
# Condition             5
# Overall Rating       44
# dtype: int64

# %%
## DATA SELECTION
df1.drop(['Condition'], axis=1, inplace=True)
df1
# Out:
#       Position   Player Name          Team Name Nationality  Height  Weight  \
# 0           CF    C. RONALDO     PM BLACK WHITE    PORTUGAL     185      80
# 1           SS      L. MESSI          BARCELONA   ARGENTINA     170      72
# 2          LWF        NEYMAR                PSG      BRAZIL     175      68
# 3           GK  DAVID DE GEA            MAN RED       SPAIN     192      76
# 4           GK      M. NEUER        Free Agents     GERMANY     193      92
# ...        ...           ...                ...         ...     ...     ...
# 11143       GK       R. FROM       NORDSJÆLLAND     DENMARK     180      78
# 11144       CB      G. MUTLU        AKHİSARSPOR      TURKEY     170      68
# 11145      CMF   ZHU ZHENGYU      SHANGHAI SIPG       CHINA     178      71
# 11146       GK    A. CÁCERES    UNIÓN LA CALERA       CHILE     175      72
# 11147      AMF     B. KIRDAR  MELBOURNE VICTORY   AUSTRALIA     178      75
#
#        Age  Overall Rating
# 0       33              94
# ...

# %%
df1[['Player Name','Overall Rating']][df1['Overall Rating'] >= 80]
# Out:
#       Player Name  Overall Rating
# 0      C. RONALDO              94
# 1        L. MESSI              94
# 2          NEYMAR              93
# 3    DAVID DE GEA              91
# 4        M. NEUER              90
# ..            ...             ...
# 572     F. CHIESA              80
# 573   DAVID NERES              80
# 574      W. NDIDI              80
# 575          XAVI              80
# 576       M. BERG              80
#
# [577 rows x 2 columns]

# %%
df1[['Player Name','Overall Rating']][df1['Overall Rating'] >= 80].iloc[500:600]
# Out:
#       Player Name  Overall Rating
# 500    G. RAMÍREZ              80
# 501      S. LULIĆ              80
# 502  N. JØRGENSEN              80
# 503       D. VIDA              80
# 504          DUDU              80
# ..            ...             ...
# 572     F. CHIESA              80
# 573   DAVID NERES              80
# 574      W. NDIDI              80
# 575          XAVI              80
# 576       M. BERG              80
#
# [77 rows x 2 columns]

# %%
## Aggregate Functions 
df1.describe()
# Out:
#              Height        Weight           Age  Overall Rating
# count  11148.000000  11148.000000  11148.000000    11148.000000
# mean     180.757894     74.909490     25.533549       69.156172
# std        6.810113      6.828361      4.788020        6.431950
# min      155.000000     50.000000     15.000000       50.000000
# 25%      176.000000     70.000000     22.000000       64.000000
# 50%      180.000000     75.000000     25.000000       69.000000
# 75%      185.000000     79.000000     29.000000       74.000000
# max      203.000000    113.000000     45.000000       94.000000

# %%
df1.corr()
# Out:
#                   Height    Weight       Age  Overall Rating
# Height          1.000000  0.746630  0.130369        0.099392
# Weight          0.746630  1.000000  0.215881        0.130131
# Age             0.130369  0.215881  1.000000        0.464184
# Overall Rating  0.099392  0.130131  0.464184        1.000000

# %%
df1['Position'].value_counts()
# Out:
# CB     1893
# CF     1504
# CMF    1353
# GK     1280
# DMF     878
# LB      835
# RB      833
# AMF     725
# RWF     464
# LWF     453
# LMF     414
# RMF     369
# SS      147
# Name: Position, dtype: int64

# %%
## DATA CLEANING 
df1.isnull().sum()
#df[‘Age’].fillna(df[‘Age’].mean())
# Out:
# Position          0
# Player Name       0
# Team Name         0
# Nationality       0
# Height            0
# Weight            0
# Age               0
# Overall Rating    0
# dtype: int64

# %%
#Group BY
df1.groupby('Nationality').mean()
# Out:
#                          Height     Weight        Age  Overall Rating
# Nationality
# ALBANIA              181.648649  75.297297  25.405405       68.837838
# ALGERIA              180.326087  73.847826  27.239130       72.565217
# ANGOLA               178.272727  73.181818  26.090909       69.272727
# ANTIGUA AND BARBUDA  178.000000  73.000000  23.000000       69.000000
# ARGENTINA            178.698498  74.857296  25.930258       70.777897
# ...                         ...        ...        ...             ...
# VENEZUELA            179.461538  74.230769  25.403846       69.826923
# VIETNAM              181.000000  76.000000  30.000000       59.000000
# WALES                181.290909  75.800000  25.818182       69.872727
# ZAMBIA               180.000000  76.000000  24.250000       68.500000
# ZIMBABWE             175.000000  70.166667  27.333333       70.333333
#
# [147 rows x 4 columns]

# %%
df1.groupby(['Nationality','Position']).mean()
# Out:
#                           Height     Weight        Age  Overall Rating
# Nationality Position
# ALBANIA     AMF       174.000000  70.000000  21.000000       63.000000
#             CB        187.000000  82.333333  27.333333       73.000000
#             CF        187.200000  76.600000  25.000000       66.200000
#             CMF       180.250000  76.750000  24.750000       68.250000
#             DMF       177.166667  71.833333  28.000000       71.166667
# ...                          ...        ...        ...             ...
# ZIMBABWE    DMF       177.000000  71.000000  24.000000       79.000000
#             LWF       174.000000  68.000000  28.000000       74.000000
#             RB        178.000000  77.000000  27.000000       71.000000
#             RWF       170.000000  64.000000  29.000000       60.000000
#             SS        168.000000  69.000000  34.000000       69.000000
#
# [1107 rows x 4 columns]

# %%
df1[df1['Nationality'] == 'ALBANIA'].groupby('Position').mean()
# Out:
#               Height     Weight        Age  Overall Rating
# Position
# AMF       174.000000  70.000000  21.000000       63.000000
# CB        187.000000  82.333333  27.333333       73.000000
# CF        187.200000  76.600000  25.000000       66.200000
# CMF       180.250000  76.750000  24.750000       68.250000
# DMF       177.166667  71.833333  28.000000       71.166667
# GK        191.333333  83.666667  27.666667       76.333333
# LB        179.333333  72.000000  25.000000       67.000000
# LMF       179.000000  73.500000  21.500000       62.500000
# RB        180.500000  72.500000  25.250000       71.250000
# RMF       175.666667  70.000000  24.333333       65.666667
# RWF       182.333333  78.000000  23.333333       65.666667

# %%
#df3 = pd.concat([df1,df2],axis=0)#concat is the same as an SQL UNION

# %%
#df3 = pd.merge(df1,df2, how='Left, on='Nationality')

# %%
##Data Manipulation
df1
# Out:
#       Position   Player Name          Team Name Nationality  Height  Weight  \
# 0           CF    C. RONALDO     PM BLACK WHITE    PORTUGAL     185      80
# 1           SS      L. MESSI          BARCELONA   ARGENTINA     170      72
# 2          LWF        NEYMAR                PSG      BRAZIL     175      68
# 3           GK  DAVID DE GEA            MAN RED       SPAIN     192      76
# 4           GK      M. NEUER        Free Agents     GERMANY     193      92
# ...        ...           ...                ...         ...     ...     ...
# 11143       GK       R. FROM       NORDSJÆLLAND     DENMARK     180      78
# 11144       CB      G. MUTLU        AKHİSARSPOR      TURKEY     170      68
# 11145      CMF   ZHU ZHENGYU      SHANGHAI SIPG       CHINA     178      71
# 11146       GK    A. CÁCERES    UNIÓN LA CALERA       CHILE     175      72
# 11147      AMF     B. KIRDAR  MELBOURNE VICTORY   AUSTRALIA     178      75
#
#        Age  Overall Rating
# 0       33              94
# ...

# %%
def BMI(weight,height):
    bmi = weight/(height/100)**2 
    return bmi

# %%
#Calculate BMI of every player
df1['BMI'] = df1.apply(lambda x: BMI(x['Weight'],x['Height']), axis=1)
df1
# Out:
#       Position   Player Name          Team Name Nationality  Height  Weight  \
# 0           CF    C. RONALDO     PM BLACK WHITE    PORTUGAL     185      80
# 1           SS      L. MESSI          BARCELONA   ARGENTINA     170      72
# 2          LWF        NEYMAR                PSG      BRAZIL     175      68
# 3           GK  DAVID DE GEA            MAN RED       SPAIN     192      76
# 4           GK      M. NEUER        Free Agents     GERMANY     193      92
# ...        ...           ...                ...         ...     ...     ...
# 11143       GK       R. FROM       NORDSJÆLLAND     DENMARK     180      78
# 11144       CB      G. MUTLU        AKHİSARSPOR      TURKEY     170      68
# 11145      CMF   ZHU ZHENGYU      SHANGHAI SIPG       CHINA     178      71
# 11146       GK    A. CÁCERES    UNIÓN LA CALERA       CHILE     175      72
# 11147      AMF     B. KIRDAR  MELBOURNE VICTORY   AUSTRALIA     178      75
#
#        Age  Overall Rating        BMI
# ...

# %%
df1.describe()
# Out:
#              Height        Weight           Age  Overall Rating           BMI
# count  11148.000000  11148.000000  11148.000000    11148.000000  11148.000000
# mean     180.757894     74.909490     25.533549       69.156172     22.906643
# std        6.810113      6.828361      4.788020        6.431950      1.390547
# min      155.000000     50.000000     15.000000       50.000000     16.787190
# 25%      176.000000     70.000000     22.000000       64.000000     22.038401
# 50%      180.000000     75.000000     25.000000       69.000000     22.981902
# 75%      185.000000     79.000000     29.000000       74.000000     23.766410
# max      203.000000    113.000000     45.000000       94.000000     30.863007

# %%
## K-Means clustering
#Cluster players based on Position,Height, Weight, Age and compare clustering with adding Overall Rating
#from sklearn.model_selection import train_test_split

X = pd.concat([pd.get_dummies(df1['Position']),df1['Height'],df1['Weight'],df1['Age'],df1['BMI']], axis=1)
#y = df1['Overall Rating']

# %%
#Then calculate best k parameter
from sklearn.cluster import KMeans 
from sklearn import metrics 
from scipy.spatial.distance import cdist

distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,10) 
  
for k in K: 
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=k).fit(X) 
    kmeanModel.fit(X)     
      
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                      'euclidean'),axis=1)) / X.shape[0]) 
    inertias.append(kmeanModel.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                 'euclidean'),axis=1)) / X.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
for key,val in mapping1.items(): 
    print(str(key)+' : '+str(val))
# Out:
# 1 : 9.848505387490924
# 2 : 7.4254593774144055
# 3 : 6.577557287046482
# 4 : 6.004690628146739
# 5 : 5.628886238816997
# 6 : 5.328924159638784
# 7 : 5.099116962189124
# 8 : 4.882681692503009
# 9 : 4.7130113499235815

# %%
plt.plot(K, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()

# %%
for key,val in mapping2.items(): 
    print(str(key)+' : '+str(val))
# Out:
# 1 : 1323821.8952351394
# 2 : 726759.9485495532
# 3 : 564811.6004454872
# 4 : 474051.7752703521
# 5 : 418347.2747038137
# 6 : 375052.65131530055
# 7 : 342279.71699655784
# 8 : 313658.85650307784
# 9 : 291942.45878305455

# %%
plt.plot(K, inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %%
##Now using yellowbrick from scikit
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,9), locate_elbow=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
##Elbow method shows us that K = 2 so we settle on our hyper parameter and train the model and add cluster labels as new column 
model = KMeans(n_clusters=2)
model.fit(X)
df1['Cluster_Labels'] = model.labels_
df1
# Out:
#       Position   Player Name          Team Name Nationality  Height  Weight  \
# 0           CF    C. RONALDO     PM BLACK WHITE    PORTUGAL     185      80
# 1           SS      L. MESSI          BARCELONA   ARGENTINA     170      72
# 2          LWF        NEYMAR                PSG      BRAZIL     175      68
# 3           GK  DAVID DE GEA            MAN RED       SPAIN     192      76
# 4           GK      M. NEUER        Free Agents     GERMANY     193      92
# ...        ...           ...                ...         ...     ...     ...
# 11143       GK       R. FROM       NORDSJÆLLAND     DENMARK     180      78
# 11144       CB      G. MUTLU        AKHİSARSPOR      TURKEY     170      68
# 11145      CMF   ZHU ZHENGYU      SHANGHAI SIPG       CHINA     178      71
# 11146       GK    A. CÁCERES    UNIÓN LA CALERA       CHILE     175      72
# 11147      AMF     B. KIRDAR  MELBOURNE VICTORY   AUSTRALIA     178      75
#
#        Age  Overall Rating        BMI  Cluster_Labels
# ...

# %%
##Given our data it seems that there are two modes given our list of features. We can now use our model to group our data
#based on these two modes and then do inferential stats, or more modelign based on each cluster group. We can also use the model to help us organize new incoming data
#whenever we decide to update our data frame.
